# %%
import pandas as pd 
melb_data = pd.read_csv('C:/IDE/data/melb_data_fe.csv', sep=',')
melb_df = melb_data.copy()
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %%
# Задание 1.1
melb_df['Date'] = pd.to_datetime(melb_df['Date'], yearfirst=True)
quarter_sold = melb_df['Date'].dt.quarter
quarter_sold.value_counts()
# Out:
# Date
# 3    4873
# 2    4359
# 4    2329
# 1    2019
# Name: count, dtype: int64

# %%
# Задание 1.2
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
max_unique_count = 150
for col in melb_df.columns:
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude:
        melb_df[col] = melb_df[col].astype('category')
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 2652  2016-03-09       6.4      3011        1  ...   144.89000
# 1805  2017-02-25       8.9      3162        4  ...   145.02420
# ...

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#              Suburb  Rooms   Type      Price Method    SellerG       Date  \
# 11144     Northcote      4  house  1955000.0     SP    McGrath 2017-12-08
# 11217  Surrey Hills      3  house  1775000.0     PI     Jellis 2017-12-08
# 11206      St Kilda      4  house  1600000.0     VB       Gary 2017-12-08
# 11207    Strathmore      7  house  2000000.0     SP     Nelson 2017-12-08
# 11208    Strathmore      4  house  1610000.0      S      other 2017-12-08
# ...             ...    ...    ...        ...    ...        ...        ...
# 1555     Camberwell      4  house  2650000.0      S     Jellis 2016-03-09
# 4510       Oak Park      3  house   892000.0      S     Nelson 2016-03-09
# 4388      Northcote      3  house  1200000.0      S     Nelson 2016-03-09
# 6184   Surrey Hills      3  house  1205000.0      S  Fletchers 2016-01-28
# 6183   Surrey Hills      2   unit   813000.0      S  Fletchers 2016-01-28
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# ...

# %%
melb_df.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
mask1 = melb_df['AreaRatio'] < -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'
melb_df[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#          Date  AreaRatio
# 0  2016-03-09  -0.805556
# 1  2016-03-12  -0.835079
# 2  2016-03-12  -0.975709
# 3  2016-04-16  -0.961039
# 4  2016-04-23  -0.825485
# 5  2016-04-23  -0.947368
# 6  2016-05-14  -0.888466
# 7  2016-06-27  -0.950168
# 8  2016-06-27  -0.979167
# 9  2016-07-26  -0.974922
# 10 2016-08-10  -0.823529
# 11 2016-09-24  -0.819936
# 12 2016-09-24  -0.971831
# 13 2016-10-12  -0.945946
# 14 2016-10-12  -0.964072
# 15 2016-10-15  -0.960784
# 16 2016-11-19  -0.904669
# 17 2016-11-19  -0.951807
# 18 2016-11-27  -0.943396
# 19 2016-11-27  -0.953608
# 20 2016-12-11  -0.893881
# 21 2016-12-11  -0.945946
# 22 2017-01-07  -0.966667
# 23 2017-02-25  -0.947434
# 24 2017-02-25  -0.966202
# 25 2017-02-25  -0.968504
# 26 2017-03-09  -0.900387
# 27 2017-03-09  -1.000000
# 28 2017-04-03  -0.815661
# 29 2017-04-03  -1.000000
# 30 2017-05-13  -0.926478
# 31 2017-05-20  -0.913491
# 32 2017-05-20  -0.937188
# 33 2017-05-27  -0.846995
# 34 2017-06-05  -0.865463
# 35 2017-06-17  -0.901370
# ...

# %%
# Задание 2.2
area_sort = melb_df.sort_values(by='AreaRatio', ascending=False, ignore_index=True)
display(area_sort.loc[1558])
# Out:
# Suburb                       Elsternwick
# Rooms                                  2
# Type                               house
# Price                           716000.0
# Method                                 S
# SellerG                          McGrath
# Date                 2017-03-06 00:00:00
# Distance                             7.2
# Postcode                            3185
# Bedroom                                2
# Bathroom                               1
# Car                                    1
# Landsize                             0.0
# BuildingArea                       126.0
# CouncilArea                    Glen Eira
# Lattitude                      -37.89438
# Longtitude                     145.00851
# Regionname         Southern Metropolitan
# Propertycount                       4898
# MeanRoomsSquare                     25.2
# AreaRatio                            1.0
# MonthSale                              3
# AgeBuilding                           47
# ...

# %%
# Задание 2.3
mask_1 = melb_df['Rooms'] > 2
mask_2 = melb_df['Type'] == 'townhouse'
melb_df[mask_1 & mask_2].sort_values(
  by=['Rooms', 'MeanRoomsSquare'],
  ascending=[True, False],
  ignore_index=True  
).loc[18, ['Price']]
# Out:
# Price    1300000.0
# Name: 18, dtype: object

# %%
melb_df.groupby(by='Type').mean(numeric_only=True)
# Out:
# C:\Users\Smoking Shop\AppData\Local\Temp\ipykernel_8152\2774055988.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type').mean(numeric_only=True)
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# unit       1.128936  477.314219    102.235863 -37.823710  144.996363
#
# ...

# %%
melb_df.groupby('Type')['Price'].mean()
# Out:
# C:\Users\Smoking Shop\AppData\Local\Temp\ipykernel_8152\2328732824.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Type')['Price'].mean()
# Type
# house        1.242665e+06
# townhouse    9.337351e+05
# unit         6.051275e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# C:\Users\Smoking Shop\AppData\Local\Temp\ipykernel_8152\3783769093.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %%
melb_df.groupby('MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
).sort_values(by='count', ascending=False)
# Out:
# C:\Users\Smoking Shop\AppData\Local\Temp\ipykernel_8152\3700124206.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg(
#            count          mean        max
# MonthSale
# 8           1850  1.056371e+06  6500000.0
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 11           750  1.142503e+06  5050000.0
# 12           725  1.144737e+06  5700000.0
# 2            333  1.169051e+06  4735000.0
# 1            278  9.397921e+05  5200000.0

# %%
melb_df.groupby('MonthSale')['Price'].agg('describe')
# Out:
# C:\Users\Smoking Shop\AppData\Local\Temp\ipykernel_8152\701566850.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg('describe')
#             count          mean            std       min       25%        50%  \
# MonthSale
# 1           278.0  9.397921e+05  577668.924214  170000.0  570500.0   795000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# ...

# %%
melb_data.groupby('Regionname')['SellerG'].agg(
    ['nunique', set]
)
#display(melb_df['SellerG'])
# Out:
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Ray, Gary, RT, Buxton, Kay, Fletchers, Stockd...
# Eastern Victoria            {Ray, Fletchers, McGrath, Eview, Harcourts, ot...
# Northern Metropolitan       {Ray, LITTLE, Cayzer, RT, Kay, Alexkarbon, Fle...
# Northern Victoria           {Ray, Buckingham, McGrath, LITTLE, other, Barr...
# South-Eastern Metropolitan  {Ray, Thomson, Gary, Buxton, Chisholm, Fletche...
# Southern Metropolitan       {Ray, LITTLE, Thomson, Cayzer, Gary, RT, Chish...
# ...

# %%
# Задание 3.1
melb_df.groupby('Rooms')['Price'].mean().sort_values(ascending=False)
# Out:
# Rooms
# 7     1.920700e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 8     1.602750e+06
# 4     1.445282e+06
# 3     1.076081e+06
# 10    9.000000e+05
# 2     7.750812e+05
# 1     4.338245e+05
# Name: Price, dtype: float64

# %%
# Задание 3.2
melb_df.groupby('Regionname')['Lattitude'].std().sort_values()
# Out:
# C:\Users\Smoking Shop\AppData\Local\Temp\ipykernel_8152\400397108.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Lattitude'].std().sort_values()
# Regionname
# Western Victoria              0.011579
# Southern Metropolitan         0.043080
# Eastern Metropolitan          0.047890
# Northern Metropolitan         0.049639
# Western Metropolitan          0.051251
# South-Eastern Metropolitan    0.073411
# Northern Victoria             0.084455
# Eastern Victoria              0.147067
# Name: Lattitude, dtype: float64

# %%
melb_df['SellerG'] = melb_data['SellerG']
display(melb_df['SellerG'])
# Out:
# 0          Biggin
# 1          Biggin
# 2          Biggin
# 3          Biggin
# 4          Nelson
#            ...
# 13575       Barry
# 13576    Williams
# 13577       Raine
# 13578     Sweeney
# 13579     Village
# Name: SellerG, Length: 13580, dtype: object

# %%
display(melb_df['Date'])
# Out:
# 0       2016-03-12
# 1       2016-04-02
# 2       2017-04-03
# 3       2017-04-03
# 4       2016-04-06
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
# Задание 3.3
date_mask = pd.to_datetime('2017-09-01') - pd.to_datetime('2017-05-01')
print(date_mask)
melb_df[melb_df['SellerG']['Date'] == date_mask]['Price'].sum()
# Out:
# 123 days 00:00:00
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 4
#       2 date_mask = pd.to_datetime('2017-09-01') - pd.to_datetime('2017-05-01')
#       3 print(date_mask)
# ----> 4 melb_df[melb_df['SellerG']['Date'] == date_mask]['Price'].sum()
#
# File c:\Users\Smoking Shop\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File c:\Users\Smoking Shop\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
# ...
