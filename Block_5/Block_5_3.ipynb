# %% [markdown]
# # <center>Блок 5. Математика в ML. Часть I<center>
# ## <center>*BONUS. MATH&ML-3. Линейная алгебра в контексте линейных методов. Часть III<center>
# ### <center>1.Введение<center>
# ### <center>2.Линейный оператор<center>
# #### <center>Линейный оператор<center>
# #### <center>Собственные векторы и числа<center>
# ### <center>3.Собственные векторы и числа<center>
# #### <center>Алгоритм поиска собственных векторов и чисел на примере матрицы 2х2<center>
